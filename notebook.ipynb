# %%
import pandas as pd
df = pd.read_csv("animes.csv")

# %%
df
# Out:
#        animeID                                              title  \
# 0            1                               Howl's Moving Castle
# 1            2                                         Death Note
# 2            3  Problem Children Are Coming from Another World...
# 3            4                                            BTOOOM!
# 4            5                                   Sword Art Online
# ...        ...                                                ...
# 20232    20233                              Manabu no Natsuyasumi
# 20233    20234                                    Merry PLLIstmas
# 20234    20235                                            Moonset
# 20235    20236                             Fuwa's Olympic Stories
# 20236    20237                                          Hyper ERT
#
#                                      alternative_title     type  year score  \
# 0                                  Howl no Ugoku Shiro    MOVIE  2004  8.41
# ...

# %%
df.head()
# Out:
#    animeID                                              title  \
# 0        1                               Howl's Moving Castle
# 1        2                                         Death Note
# 2        3  Problem Children Are Coming from Another World...
# 3        4                                            BTOOOM!
# 4        5                                   Sword Art Online
#
#                                  alternative_title   type  year score  \
# 0                              Howl no Ugoku Shiro  MOVIE  2004  8.41
# 1                                              NaN     TV  2006  8.63
# 2  Mondaiji-tachi ga Isekai kara Kuru Sou desu yo?     TV  2013  7.42
# 3                                          Btooom!     TV  2012  7.34
# 4                                              NaN     TV  2012   7.5
#
#    episodes                              mal_url  sequel  \
# 0         1    https://myanimelist.net/anime/431   False
# ...

# %%
df.tail()
# Out:
#        animeID                   title    alternative_title     type  year  \
# 20232    20233   Manabu no Natsuyasumi                  NaN      OVA  2005
# 20233    20234         Merry PLLIstmas                  NaN  SPECIAL  2023
# 20234    20235                 Moonset               Tsukio  SPECIAL  2018
# 20235    20236  Fuwa's Olympic Stories  Fuwa Aoyun Manyouji       TV  2007
# 20236    20237               Hyper ERT                  NaN       TV  2008
#
#       score  episodes                              mal_url  sequel  \
# 20232  4.95         1  https://myanimelist.net/anime/24019   False
# 20233     ?         1  https://myanimelist.net/anime/57643   False
# 20234     ?         1  https://myanimelist.net/anime/57686   False
# 20235  4.82       100   https://myanimelist.net/anime/9949   False
# 20236  4.68        20   https://myanimelist.net/anime/9902   False
#
#                                                image_url       genres  \
# ...

# %%
df.loc[df["score"] == '?']
#df.tail()
# Out:
#        animeID                                              title  \
# 8209      8210      Saezuru Tori wa Habatakanai: The Storm Breaks
# 9058      9059                 Mairimashita! Iruma-kun 4th Season
# 9376      9377                                  Lord of Mysteries
# 10989    10990                             Sabikui Bisco Season 2
# 12264    12265  Class de 2-banme ni Kawaii Onnanoko to Tomodac...
# ...        ...                                                ...
# 20215    20216                                  Ikimono-san Pilot
# 20221    20222                              Moshi Juexing: Suyuan
# 20225    20226                                   Season of Change
# 20233    20234                                    Merry PLLIstmas
# 20234    20235                                            Moonset
#
#                   alternative_title     type  year score  episodes  \
# 8209                            NaN    MOVIE     ?     ?         1
# ...

# %%
df.drop(df[df["type"] == "ONA"].index, inplace=True)
df.drop(df[df["type"] == "OVA"].index, inplace=True)
df.drop(df[df["type"] == "SPECIAL"].index, inplace=True)
df.drop(df[df["score"] == '?'].index, inplace=True)

df["score"] = df["score"].astype(float)
df.drop(df[df["score"] < 7].index, inplace=True)

df.drop(df[df["year"] == '?'].index, inplace=True)
df["year"] = df["year"].astype (int)

df.drop(df[df["genres"] == "['Hentai']"].index, inplace=True) 
   
# df.loc[df["score"] == '?']
# df.loc[df["year"] == '?']
# df.loc[df["type"] == "SPECIAL"]
# df.loc[df["genres"] == "['Hentai']"]
# df.loc[df["genres"] == "[]"]
# df.loc[df["sequel"] == False]

# %%
df
# Out:
#        animeID                                              title  \
# 0            1                               Howl's Moving Castle
# 1            2                                         Death Note
# 2            3  Problem Children Are Coming from Another World...
# 3            4                                            BTOOOM!
# 4            5                                   Sword Art Online
# ...        ...                                                ...
# 19393    19394                                    White Fireworks
# 19565    19566  Edutainment Planetarium Doraemon to Chigasou: ...
# 19608    19609                Jujutsu Kaisen: Kaigyoku/Gyokusetsu
# 19663    19664                                Realm of Terracotta
# 20220    20221   Power Battle Watch Car: Return of the Watch Mask
#
#                                        alternative_title   type  year  score  \
# 0                                    Howl no Ugoku Shiro  MOVIE  2004   8.41
# ...
